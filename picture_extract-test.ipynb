# %%
import csv
import numpy


with open('/Users/jj9754/Desktop/TAMU20SPRING/CSCE636/course_project/ava_val_v2.2.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

data[1][0]
# Out:
# '1j20qq1JyX4'

# %%
label_val=[x[6] for x in data]
#print(label_train)
y=-1
video_list=[]
for x in label_val:
    #print(x[6])
    y=y+1
    if (x=='63'):
        #print(0)
        video_list.append(data[y][0])
#print(video_list) 
    # download the video

# %%
video_list=list(set(video_list))
print(video_list)
len(video_list)
# Out:
# ['fpprSy6AzKk', '_eBah6c5kyA', 'ayAMdYfJJLk', 'covMYDBa5dk', 'ZosVdkY76FU', '9Y_l9NsnYE0', 'sNQJfYvhcPk', 'Ov0za6Xb1LM', 'SCh-ZImnyyk', 'KVq6If6ozMY', 'Lg1jOu8cUBM', 'WSPvfxtqisg', 'b-YoBU0XT90', 'O_NYCUhZ9zw', 'rXFlJbXyZyc', 'yn9WN9lsHRE', 'bePts02nIY8', 'NO2esmws190', 'KHHgQ_Pe4cI', '9F2voT6QWvQ', 'jE0S8gYWftE', 'IzvOYVMltkI']
# 22

# %%
print(video_list[13:])
# Out:
# ['O_NYCUhZ9zw', 'rXFlJbXyZyc', 'yn9WN9lsHRE', 'bePts02nIY8', 'NO2esmws190', 'KHHgQ_Pe4cI', '9F2voT6QWvQ', 'jE0S8gYWftE', 'IzvOYVMltkI']

# %%
dic=dict.fromkeys(video_list)
for x in data:
    if x[6]=='63':
        if dic[x[0]]:
            dic[x[0]].append(int(x[1]))
        else:
            dic[x[0]]=[int(x[1])]
print(dic.get('rXFlJbXyZyc'))
print(dic.get('9F2voT6QWvQ'))
print(dic.get('jE0S8gYWftE'))
print(dic.get('yn9WN9lsHRE'))
print(dic.get('WSPvfxtqisg'))
print(sum(len(dic[x]) for x in video_list))
# Out:
# [902, 903, 904, 905, 1528, 1531, 1532, 1533, 1534]
# [938, 938, 939, 940, 940, 941, 941, 942, 943, 943, 944, 978, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742]
# [1211, 1212, 1258, 1259, 1259, 1260, 1260, 1261, 1261, 1262, 1262, 1263, 1263, 1264, 1264, 1265, 1266, 1266, 1267, 1268, 1279, 1280, 1282, 1283]
# [1171, 1184, 1194, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1237, 1238, 1239, 1242, 1243, 1244, 1245, 1246]
# [1170, 1171, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182]
# 274

# %%
import numpy as np
dic_no=dict.fromkeys(video_list)
for x in data:
    if x[0] in dic_no:
        if x[1] not in dic.get(x[0]):
            ran=numpy.random.choice(numpy.arange(0, 2), p=[0.03, 0.97])
            if ran==0:
                if dic_no[x[0]]:
                    dic_no[x[0]].append(int(x[1]))
                else:
                    dic_no[x[0]]=[int(x[1])]
print(dic.get('Ov0za6Xb1LM'))
print(sum(len(dic_no[x]) for x in video_list))
# Out:
# [1131, 1132, 1541, 1543, 1544, 1545, 1546, 1547, 1548]
# 262

# %%
import os
folder1= 'test_writing'  
os.mkdir(folder1)

# %%
import os
folder2='test_nowriting'
os.mkdir(folder2)

# %%
import requests
import cv2
i=0
count=0
count_no=0
for name in video_list:
    j=str(i)
    request1 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.mp4')
    request2 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.mkv')
    request3 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.webm')
    if request1.status_code == 200:
        open('train'+j+'.mp4', 'wb').write(request1.content)
        video_name='train'+j+'.mp4'
    elif request2.status_code == 200:
        open('train'+j+'.mkv', 'wb').write(request2.content)
        video_name='train'+j+'.mkv'
        #print('Web site does not exist') 
    else:
        open('train'+j+'.webm', 'wb').write(request3.content)
        video_name='train'+j+'.webm'
    
    for x in dic.get(name):
        cap = cv2.VideoCapture(video_name) #video\_name is the video being called
        cap.set(0,x*1000); # Where frame\_no is the frame you want
        ret, frame = cap.read() # Read the frame
        print(ret)
        cv2.imwrite(os.path.join(folder1,"frame{:d}.jpg".format(count)), frame)
        count=count+1
    for i in dic_no.get(name):
        cap_no = cv2.VideoCapture(video_name) #video\_name is the video being called
        cap_no.set(0,i*1000); # Where frame\_no is the frame you want
        ret, frame = cap_no.read() # Read the frame
        print("nowriting",ret)
        cv2.imwrite(os.path.join(folder2,"frame{:d}.jpg".format(count_no)), frame)
        count_no=count_no+1
    os.remove(video_name)
    i=i+1
    print(name,i)
# Out:
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# fpprSy6AzKk 1
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# _eBah6c5kyA 2
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# ayAMdYfJJLk 3
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# covMYDBa5dk 4
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# ZosVdkY76FU 5
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# 9Y_l9NsnYE0 6
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# sNQJfYvhcPk 7
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# Ov0za6Xb1LM 8
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# SCh-ZImnyyk 9
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# KVq6If6ozMY 10
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# Lg1jOu8cUBM 11
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# WSPvfxtqisg 12
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# b-YoBU0XT90 13
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# O_NYCUhZ9zw 14
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# rXFlJbXyZyc 15
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# yn9WN9lsHRE 16
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# bePts02nIY8 17
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# NO2esmws190 18
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# KHHgQ_Pe4cI 19
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# 9F2voT6QWvQ 20
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# jE0S8gYWftE 21
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# IzvOYVMltkI 22

# %%
video_list[24:]
# Out:
# ['eA55_shhKko',
#  'lWXhqIAvarw',
#  'Ksd1JQFHYWA',
#  't0V4drbYDnc',
#  'zR725veL-DI',
#  '4Y5qi1gD2Sw',
#  '5LrOQEt_XVM',
#  '8VZEwOCQ8bc',
#  'U_WzY2k8IBM',
#  'SHBMiL5f_3Q',
#  'XV_FF3WC7kA',
#  '7g37N3eoQ9s',
#  'HV0H6oc4Kvs',
#  'UsLnxI_zGpY',
#  'UOfuzrwkclM',
#  'qrkff49p4E4',
#  'gjasEUDkbuc',
#  '_-Z6wFjXtGQ',
#  'tjqCzVjojCo',
#  '9mLYmkonWZQ',
#  '7YpF6DntOYw',
#  'rJKeqfTlAeY',
#  'bAVXp1oGjHA',
#  'phVLLTMzmKk',
#  'BY3sZmvUp-0',
#  'z3kgrh0L_80',
#  'KWoSGtglCms',
#  'xJmRNZVDDCY',
#  'xO4ABy2iOQA',
#  '053oq2xB3oU',
#  'T-Fc9ctuNVI',
#  'lT1zdTL-3SM',
#  'pGP_oIdKmRY',
#  '2E_e8JlvTlg',
#  '4ZpjKfu6Cl8',
#  'K_SpqDJnlps',
#  'tEoJW9ycmSY',
#  '1ReZIMmD_8E',
#  '2fwni_Kjf2M',
#  'r2llOyS-BmE',
#  'oq_bufAhyl8',
#  'v0L-WkMO3s4',
#  'uq_HBsvP548',
#  'b50s4AlOOKY',
#  '2FIHxnZKg6A',
#  'QaIMUi-elFo',
#  'TCmNvNLRWrc',
#  '9tyiDEYiWiA',
#  'wfEOx36N4jA',
#  'P60OxWahxBQ',
#  'N0Dt9i9IUNg',
#  'QotkBTEePI8',
#  'wogRuPNBUi8',
#  'phrYEKv0rmw',
#  '9IF8uTRrWAM',
#  'HKjR70GCRPE',
#  '-XpUuIgyUHE',
#  'IuPC-z-M9u8',
#  'jI0HIlSsa3s',
#  'cWYJHb25EVs',
#  'C3qk4yAMANk',
#  'mfsbYdLx9wE',
#  'AYebXQ8eUkM',
#  'cc4y-yYm5Ao',
#  'PNZQ2UJfyQE',
#  'Vmef_8MY46w',
#  '_Ca3gOdOHxU',
#  'LrDT25hmApw',
#  'vfjywN5CN0Y',
#  'BCiuXAuCKAU',
#  'OfMdakd4bHI']

# %%
print(count)
print(count_no)
# Out:
# 151
# 246

# %%
import requests
import cv2
import os
i=0
request1 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+'XF87VL5T0aA'+'.mkv')
open('train'+str(i)+'.mkv','wb').write(request1.content)
video_name='train'+str(i)+'.mkv'

# %%
name
# Out:
# 'eA55_shhKko'

# %%
count=0
for x in dic.get('XF87VL5T0aA'):
    cap = cv2.VideoCapture(video_name) #video\_name is the video being called
    cap.set(0,x*1000); # Where frame\_no is the frame you want
    ret, frame = cap.read() # Read the frame
    print(ret)
    cv2.imwrite(os.path.join(folder,"frame{:d}.jpg".format(count)), frame)
    count=count+1
# Out:
# True
# True

# %%
import numpy as np
#len(dic.get('XF87VL5T0aA'))
print(np.sum(len(dic.get(name)) for name in dic))
# Out:
# 777
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(np.sum(len(dic_no.get(name)) for name in dic_no))
# Out:
# 1879
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   """Entry point for launching an IPython kernel.

# %%
video_list = []
print(args.path_dir)
if args.path_dir:
    for root, dirs, files in os.walk(args.path_dir):
        for file in files:
            if '.mp4' in file:
                video_list.append(os.path.join(root, file))
